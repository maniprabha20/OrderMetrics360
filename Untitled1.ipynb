# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

credentials = service_account.Credentials.from_service_account_file(
    "/Users/student/Downloads/ordermetrics360-1b2c7e064813.json"
)

client = bigquery.Client(
    project="ordermetrics360",
    credentials=credentials
)

print("BigQuery connection successful!")
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/api_core/_python_version_support.py:242: FutureWarning: You are using a non-supported Python version (3.9.6). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/auth/__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/oauth2/__init__.py:40: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# BigQuery connection successful!

# %%
query = """
SELECT *
FROM `ordermetrics360.ordermetrics360_marts.mart_revenue_trend`
"""

df = client.query(query).to_dataframe()

df.shape
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# (25, 4)

# %%
df.head()
# Out:
#   order_month  order_count    revenue  average_order_value
# 0  2016-09-01            4     267.36            66.840000
# 1  2016-10-01          324   49507.66           152.801420
# 2  2016-12-01            1      10.90            10.900000
# 3  2017-01-01          800  120312.87           150.391087
# 4  2017-02-01         1780  247303.02           138.934281

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_month          25 non-null     dbdate
#  1   order_count          25 non-null     Int64
#  2   revenue              24 non-null     float64
#  3   average_order_value  24 non-null     float64
# dtypes: Int64(1), dbdate(1), float64(2)
# memory usage: 953.0 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_month          25 non-null     dbdate
#  1   order_count          25 non-null     Int64
#  2   revenue              24 non-null     float64
#  3   average_order_value  24 non-null     float64
# dtypes: Int64(1), dbdate(1), float64(2)
# memory usage: 953.0 bytes

# %%
df.isnull().sum()
# Out:
# order_month            0
# order_count            0
# revenue                1
# average_order_value    1
# dtype: int64

# %%
df[df["revenue"].isnull()]
# Out:
#    order_month  order_count  revenue  average_order_value
# 24  2018-10-01            4      NaN                  NaN

# %%
df[df["order_month"] == "2018-10-01"]
# Out:
# Empty DataFrame
# Columns: [order_month, order_count, revenue, average_order_value]
# Index: []

# %%
df.iloc[24]
# Out:
# order_month            2018-10-01
# order_count                     4
# revenue                       NaN
# average_order_value           NaN
# Name: 24, dtype: object

# %%
query = """
SELECT
    order_id,
    item_revenue,
    freight_revenue,
    total_payment_value
FROM `ordermetrics360.ordermetrics360_staging.int_orders_joined`
WHERE DATE_TRUNC(DATE(order_purchase_timestamp), MONTH) = '2018-10-01'
"""

check = client.query(query).to_dataframe()
check
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[9], line 11
#       1 query = """
#       2 SELECT
#       3     order_id,
#    (...)
#       8 WHERE DATE_TRUNC(DATE(order_purchase_timestamp), MONTH) = '2018-10-01'
#       9 """
# ---> 11 check = client.query(query).to_dataframe()
#      12 check
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:2194, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype, timeout)
#    1959 def to_dataframe(
#    1960     self,
#    1961     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)
#    1982     timeout: Optional[float] = None,
#    1983 ) -> "pandas.DataFrame":
#    1984     """Return a pandas DataFrame from a QueryJob
#    1985
#    1986     Args:
#    (...)
#    2192             :mod:`shapely` library cannot be imported.
#    2193     """
# -> 2194     query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    2195     return query_result.to_dataframe(
#    2196         bqstorage_client=bqstorage_client,
#    2197         dtypes=dtypes,
#    (...)
#    2212         timeout=timeout,
#    2213     )
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/_tqdm_helpers.py:107, in wait_for_query(query_job, progress_bar_type, max_results)
#     103 progress_bar = get_progress_bar(
#     104     progress_bar_type, "Query is running", default_total, "query"
#     105 )
#     106 if progress_bar is None:
# --> 107     return query_job.result(max_results=max_results)
#     109 i = 0
#     110 while True:
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1797, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1792     remaining_timeout = None
#    1794 if remaining_timeout is None:
#    1795     # Since is_job_done() calls jobs.getQueryResults, which is a
#    1796     # long-running API, don't delay the next request at all.
# -> 1797     while not is_job_done():
#    1798         pass
#    1799 else:
#    1800     # Use a monotonic clock since we don't actually care about
#    1801     # daylight savings or similar, just the elapsed time.
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/api_core/retry/retry_base.py:216, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     210 if not predicate_fn(exc):
#     211     final_exc, source_exc = exc_factory_fn(
#     212         error_list,
#     213         RetryFailureReason.NON_RETRYABLE_ERROR,
#     214         original_timeout,
#     215     )
# --> 216     raise final_exc from source_exc
#     217 if on_error_fn is not None:
#     218     on_error_fn(exc)
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1746, in QueryJob.result.<locals>.is_job_done()
#    1723 if job_failed_exception is not None:
#    1724     # Only try to restart the query job if the job failed for
#    1725     # a retriable reason. For example, don't restart the query
#    (...)
#    1743     # into an exception that can be processed by the
#    1744     # `job_retry` predicate.
#    1745     restart_query_job = True
# -> 1746     raise job_failed_exception
#    1747 else:
#    1748     # Make sure that the _query_results are cached so we
#    1749     # can return a complete RowIterator.
#    (...)
#    1755     # making any extra API calls if the previous loop
#    1756     # iteration fetched the finished job.
#    1757     self._reload_query_results(
#    1758         retry=retry, **reload_query_results_kwargs
#    1759     )
#
# NotFound: 404 Not found: Table ordermetrics360:ordermetrics360_staging.int_orders_joined was not found in location asia-south1; reason: notFound, message: Not found: Table ordermetrics360:ordermetrics360_staging.int_orders_joined was not found in location asia-south1
#
# Location: asia-south1
# Job ID: 26b94e69-852b-41f7-bf2c-3e482e00d38e

# %%
query = """
SELECT
    table_schema,
    table_name
FROM `ordermetrics360.region-asia-south1.INFORMATION_SCHEMA.TABLES`
WHERE table_name LIKE '%int_orders_joined%'
"""

client.query(query).to_dataframe()
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#       table_schema         table_name
# 0  ordermetrics360  int_orders_joined

# %%
query = """
SELECT
    order_id,
    item_revenue,
    freight_revenue,
    total_payment_value
FROM `ordermetrics360.ordermetrics360.int_orders_joined`
WHERE DATE_TRUNC(DATE(order_purchase_timestamp), MONTH) = '2018-10-01'
"""

check = client.query(query).to_dataframe()
check
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                            order_id  item_revenue  freight_revenue  \
# 0  a2ac6dad85cf8af5b0afb510a240fe8c           NaN              NaN
# 1  616fa7d4871b87832197b2a137a115d2           NaN              NaN
# 2  10a045cdf6a5650c21e9cfeb60384c16           NaN              NaN
# 3  b059ee4de278302d550a3035c4cdb740           NaN              NaN
#
#    total_payment_value
# 0               197.55
# 1                80.38
# 2                89.71
# 3               222.03

# %%
query = """
SELECT
    order_id,
    product_id,
    price,
    freight_value
FROM `ordermetrics360.ordermetrics360.order_items`
WHERE order_id IN (
    'a2ac6dad85cf8af5b0afb510a240fe8c',
    '616fa7d4871b87832197b2a137a115d2',
    '10a045cdf6a5650c21e9cfeb60384c16',
    'b059ee4de278302d550a3035c4cdb740'
)
"""

check_items = client.query(query).to_dataframe()
check_items
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Empty DataFrame
# Columns: [order_id, product_id, price, freight_value]
# Index: []

# %%
query = """
SELECT
    order_id,
    order_status,
    order_purchase_timestamp
FROM `ordermetrics360.ordermetrics360.orders`
WHERE order_id IN (
    'a2ac6dad85cf8af5b0afb510a240fe8c',
    '616fa7d4871b87832197b2a137a115d2',
    '10a045cdf6a5650c21e9cfeb60384c16',
    'b059ee4de278302d550a3035c4cdb740'
)
"""

check_orders = client.query(query).to_dataframe()
check_orders
# Out:
#                            order_id order_status  order_purchase_timestamp
# 0  a2ac6dad85cf8af5b0afb510a240fe8c     canceled 2018-10-03 18:55:29+00:00
# 1  616fa7d4871b87832197b2a137a115d2     canceled 2018-10-01 15:30:09+00:00
# 2  10a045cdf6a5650c21e9cfeb60384c16     canceled 2018-10-17 17:30:18+00:00
# 3  b059ee4de278302d550a3035c4cdb740     canceled 2018-10-16 20:16:02+00:00

# %%
df.describe()
# Out:
#        order_count       revenue  average_order_value
# count         25.0  2.400000e+01            24.000000
# mean       3977.64  5.663185e+05           124.744581
# std    2699.938516  3.566705e+05            38.960370
# min            1.0  1.090000e+01             9.062500
# 25%         1780.0  3.317712e+05           131.023348
# 50%         4285.0  5.991867e+05           136.562547
# 75%         6512.0  8.727200e+05           143.479177
# max         7544.0  1.010271e+06           152.801420

# %%
df.plot(
    x="order_month",
    y="revenue",
    kind="line",
    figsize=(12, 5),
    title="Monthly Revenue Trend"
)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: title={'center': 'Monthly Revenue Trend'}, xlabel='order_month'>

# %%
df.plot(
    x="order_month",
    y="order_count",
    kind="line",
    figsize=(12, 5),
    title="Monthly Order Trend"
)
# Out:
# <Axes: title={'center': 'Monthly Order Trend'}, xlabel='order_month'>

# %%
df.plot(
    x="order_count",
    y="revenue",
    kind="scatter",
    figsize=(8, 5),
    title="Orders vs Revenue"
)
# Out:
# <Axes: title={'center': 'Orders vs Revenue'}, xlabel='order_count', ylabel='revenue'>

# %%
df[["order_count", "revenue"]].corr()
# Out:
#              order_count   revenue
# order_count     1.000000  0.995864
# revenue         0.995864  1.000000

# %%
df.plot(
    x="order_month",
    y="average_order_value",
    kind="line",
    figsize=(12, 5),
    title="Monthly Average Order Value Trend"
)
# Out:
# <Axes: title={'center': 'Monthly Average Order Value Trend'}, xlabel='order_month'>

# %%
query = """
SELECT *
FROM `ordermetrics360.ordermetrics360_marts.mart_revenue_trend`
"""

df = client.query(query).to_dataframe()

df.tail()
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    order_month  order_count    revenue  average_order_value
# 19  2018-05-01         6833  992871.75           145.305393
# 20  2018-06-01         6145  863265.53           140.482592
# 21  2018-07-01         6233  878044.27           140.870250
# 22  2018-08-01         6421  848860.10           132.200607
# 23  2018-09-01            1     145.00           145.000000

# %%
query = """
SELECT *
FROM `ordermetrics360.ordermetrics360_marts.mart_rfm`
"""

rfm_df = client.query(query).to_dataframe()

rfm_df.head()
# Out:
# /Users/student/OrderMetrics360/venv/lib/python3.9/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                  customer_unique_id  recency  frequency  monetary
# 0  0a0a92112bd4c708ca5fde585afaa872      339          1  13664.08
# 1  da122df9eeddfedc1dc1f5349a1a690c      520          2   7571.63
# 2  763c8b1c9c68a0229c42c9fc6f662b93       50          1   7274.88
# 3  dc4802a71eae9be1dd28f5d788ceb526      568          1   6929.31
# 4  459bef486812aa25204be022145caa62       40          1   6922.21

# %%
rfm_df.describe()
# Out:
#           recency  frequency      monetary
# count     94990.0    94990.0  94989.000000
# mean   243.349479   1.033867    165.694312
# std    153.000542   0.210826    226.740844
# min           0.0        1.0      9.590000
# 25%         119.0        1.0     63.100000
# 50%         224.0        1.0    107.900000
# 75%         352.0        1.0    182.940000
# max         729.0       16.0  13664.080000

# %%
rfm_df["frequency"].value_counts().sort_index()
# Out:
# frequency
# 1     92102
# 2      2652
# 3       188
# 4        29
# 5         9
# 6         5
# 7         3
# 9         1
# 16        1
# Name: count, dtype: Int64
